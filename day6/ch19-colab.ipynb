# %% [markdown]
# # 19장 세상에 없는 얼굴 GAN, 오토인코더

# %% [markdown]
# ## 3. 적대적 신경망 실행하기

# %% [markdown]
# ### 실습: GAN 모델 만들기

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model

import numpy as np
import matplotlib.pyplot as plt

# 생성자 모델을 만듭니다.
generator = Sequential()
generator.add(Dense(128*7*7, input_dim=100, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((7, 7, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))

# 판별자 모델을 만듭니다.
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(28,28,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False

# 생성자와 판별자 모델을 연결시키는 gan 모델을 만듭니다.
ginput = Input(shape=(100,))
dis_output = discriminator(generator(ginput))
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()

# 신경망을 실행시키는 함수를 만듭니다.
def gan_train(epoch, batch_size, saving_interval):

  # MNIST 데이터를 불러옵니다.

  (X_train, _), (_, _) = mnist.load_data()  # 앞서 불러온 적 있는 MNIST를 다시 이용합니다. 단, 테스트 과정은 필요 없고 이미지만 사용할 것이기 때문에 X_train만 불러왔습니다.
  X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
  X_train = (X_train - 127.5) / 127.5  # 픽셀 값은 0에서 255 사이의 값입니다. 이전에 255로 나누어 줄때는 이를 0~1 사이의 값으로 바꾸었던 것인데, 여기서는 127.5를 빼준 뒤 127.5로 나누어 줌으로 인해 -1에서 1사이의 값으로 바뀌게 됩니다.
  # X_train.shape, Y_train.shape, X_test.shape, Y_test.shape

  true = np.ones((batch_size, 1))
  fake = np.zeros((batch_size, 1))

  for i in range(epoch):
          # 실제 데이터를 판별자에 입력하는 부분입니다.
          idx = np.random.randint(0, X_train.shape[0], batch_size)
          imgs = X_train[idx]
          d_loss_real = discriminator.train_on_batch(imgs, true)

          # 가상 이미지를 판별자에 입력하는 부분입니다.
          noise = np.random.normal(0, 1, (batch_size, 100))
          gen_imgs = generator.predict(noise)
          d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

          # 판별자와 생성자의 오차를 계산합니다.
          d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
          g_loss = gan.train_on_batch(noise, true)

          print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)

        # 이 부분은 중간 과정을 이미지로 저장해 주는 부분입니다. 이 장의 주요 내용과 관련이 없어
        # 소스 코드만 첨부합니다. 만들어진 이미지들은 gan_images 폴더에 저장됩니다.
          if i % saving_interval == 0:
              #r, c = 5, 5
              noise = np.random.normal(0, 1, (25, 100))
              gen_imgs = generator.predict(noise)

              # Rescale images 0 - 1
              gen_imgs = 0.5 * gen_imgs + 0.5

              fig, axs = plt.subplots(5, 5)
              count = 0
              for j in range(5):
                  for k in range(5):
                      axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
                      axs[j, k].axis('off')
                      count += 1
              fig.savefig("./gan_mnist_%d.png" % i)

gan_train(2001, 32, 200)  # 2000번 반복되고, 배치 사이즈는 32,  200번마다 결과가 저장되게 하였습니다.
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 100)]             0
#
#  sequential (Sequential)     (None, 28, 28, 1)         865281
#
#  sequential_1 (Sequential)   (None, 1)                 212865
#
# =================================================================
# Total params: 1,078,146
# Trainable params: 852,609
# Non-trainable params: 225,537
# _________________________________________________________________
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# 1/1 [==============================] - 0s 266ms/step
# epoch:0  d_loss:0.7033  g_loss:0.6985
# 1/1 [==============================] - 0s 161ms/step
# 1/1 [==============================] - 0s 17ms/step
# epoch:1  d_loss:0.4543  g_loss:0.3852
# 1/1 [==============================] - 0s 21ms/step
# epoch:2  d_loss:0.4773  g_loss:0.1054
# 1/1 [==============================] - 0s 16ms/step
# epoch:3  d_loss:0.6185  g_loss:0.0613
# 1/1 [==============================] - 0s 17ms/step
# epoch:4  d_loss:0.6091  g_loss:0.1243
# 1/1 [==============================] - 0s 18ms/step
# epoch:5  d_loss:0.5038  g_loss:0.3500
# 1/1 [==============================] - 0s 18ms/step
# epoch:6  d_loss:0.4372  g_loss:0.7404
# 1/1 [==============================] - 0s 18ms/step
# epoch:7  d_loss:0.4770  g_loss:0.9427
# 1/1 [==============================] - 0s 18ms/step
# epoch:8  d_loss:0.4742  g_loss:0.9273
# 1/1 [==============================] - 0s 20ms/step
# epoch:9  d_loss:0.4116  g_loss:0.8966
# 1/1 [==============================] - 0s 19ms/step
# epoch:10  d_loss:0.3800  g_loss:0.9094
# 1/1 [==============================] - 0s 16ms/step
# epoch:11  d_loss:0.4131  g_loss:0.7860
# 1/1 [==============================] - 0s 22ms/step
# epoch:12  d_loss:0.4153  g_loss:0.7309
# 1/1 [==============================] - 0s 17ms/step
# epoch:13  d_loss:0.4401  g_loss:0.8853
# 1/1 [==============================] - 0s 17ms/step
# epoch:14  d_loss:0.5671  g_loss:1.0059
# 1/1 [==============================] - 0s 19ms/step
# epoch:15  d_loss:0.5410  g_loss:1.2478
# 1/1 [==============================] - 0s 16ms/step
# epoch:16  d_loss:0.5025  g_loss:0.9675
# 1/1 [==============================] - 0s 18ms/step
# epoch:17  d_loss:0.8790  g_loss:0.6074
# 1/1 [==============================] - 0s 16ms/step
# epoch:18  d_loss:0.6807  g_loss:0.6742
# 1/1 [==============================] - 0s 17ms/step
# epoch:19  d_loss:0.5356  g_loss:0.7681
# 1/1 [==============================] - 0s 17ms/step
# epoch:20  d_loss:0.5935  g_loss:0.9190
# 1/1 [==============================] - 0s 19ms/step
# epoch:21  d_loss:0.5567  g_loss:0.9313
# 1/1 [==============================] - 0s 18ms/step
# epoch:22  d_loss:0.5042  g_loss:1.1549
# 1/1 [==============================] - 0s 19ms/step
# epoch:23  d_loss:0.5685  g_loss:1.0947
# 1/1 [==============================] - 0s 17ms/step
# epoch:24  d_loss:0.5149  g_loss:1.0677
# 1/1 [==============================] - 0s 19ms/step
# epoch:25  d_loss:0.5446  g_loss:1.0758
# 1/1 [==============================] - 0s 19ms/step
# epoch:26  d_loss:0.4982  g_loss:1.0931
# 1/1 [==============================] - 0s 20ms/step
# epoch:27  d_loss:0.5036  g_loss:1.0110
# 1/1 [==============================] - 0s 18ms/step
# epoch:28  d_loss:0.4967  g_loss:1.0682
# 1/1 [==============================] - 0s 36ms/step
# epoch:29  d_loss:0.4796  g_loss:1.0577
# 1/1 [==============================] - 0s 25ms/step
# epoch:30  d_loss:0.4712  g_loss:1.1275
# 1/1 [==============================] - 0s 36ms/step
# epoch:31  d_loss:0.4673  g_loss:1.0690
# 1/1 [==============================] - 0s 27ms/step
# epoch:32  d_loss:0.4682  g_loss:1.0162
# 1/1 [==============================] - 0s 26ms/step
# epoch:33  d_loss:0.4417  g_loss:1.0781
# 1/1 [==============================] - 0s 25ms/step
# epoch:34  d_loss:0.4361  g_loss:1.1126
# 1/1 [==============================] - 0s 24ms/step
# epoch:35  d_loss:0.4179  g_loss:1.2746
# 1/1 [==============================] - 0s 24ms/step
# epoch:36  d_loss:0.3718  g_loss:1.2717
# 1/1 [==============================] - 0s 24ms/step
# epoch:37  d_loss:0.4601  g_loss:1.0869
# 1/1 [==============================] - 0s 23ms/step
# epoch:38  d_loss:0.5241  g_loss:1.1406
# 1/1 [==============================] - 0s 35ms/step
# epoch:39  d_loss:0.4446  g_loss:1.2899
# 1/1 [==============================] - 0s 28ms/step
# epoch:40  d_loss:0.3418  g_loss:1.6143
# 1/1 [==============================] - 0s 32ms/step
# epoch:41  d_loss:0.4193  g_loss:1.2559
# 1/1 [==============================] - 0s 26ms/step
# epoch:42  d_loss:0.3967  g_loss:1.1715
# 1/1 [==============================] - 0s 25ms/step
# epoch:43  d_loss:0.3677  g_loss:1.3259
# 1/1 [==============================] - 0s 24ms/step
# epoch:44  d_loss:0.3828  g_loss:1.5572
# 1/1 [==============================] - 0s 26ms/step
# epoch:45  d_loss:0.4671  g_loss:1.7719
# 1/1 [==============================] - 0s 19ms/step
# epoch:46  d_loss:0.4185  g_loss:1.6658
# 1/1 [==============================] - 0s 18ms/step
# epoch:47  d_loss:0.4934  g_loss:1.4643
# 1/1 [==============================] - 0s 20ms/step
# epoch:48  d_loss:0.5720  g_loss:1.4490
# 1/1 [==============================] - 0s 19ms/step
# epoch:49  d_loss:0.5361  g_loss:1.7386
# 1/1 [==============================] - 0s 16ms/step
# epoch:50  d_loss:0.4331  g_loss:1.7779
# 1/1 [==============================] - 0s 18ms/step
# epoch:51  d_loss:0.5212  g_loss:1.9568
# 1/1 [==============================] - 0s 18ms/step
# epoch:52  d_loss:0.4199  g_loss:1.9120
# 1/1 [==============================] - 0s 17ms/step
# epoch:53  d_loss:0.3133  g_loss:2.3164
# 1/1 [==============================] - 0s 18ms/step
# epoch:54  d_loss:0.3007  g_loss:2.2449
# 1/1 [==============================] - 0s 17ms/step
# epoch:55  d_loss:0.2029  g_loss:2.2086
# 1/1 [==============================] - 0s 16ms/step
# epoch:56  d_loss:0.1381  g_loss:3.0409
# 1/1 [==============================] - 0s 16ms/step
# epoch:57  d_loss:0.1695  g_loss:2.5867
# 1/1 [==============================] - 0s 19ms/step
# epoch:58  d_loss:0.1725  g_loss:2.5559
# 1/1 [==============================] - 0s 18ms/step
# epoch:59  d_loss:0.3234  g_loss:2.6392
# 1/1 [==============================] - 0s 21ms/step
# epoch:60  d_loss:0.1705  g_loss:3.7914
# 1/1 [==============================] - 0s 17ms/step
# epoch:61  d_loss:0.4077  g_loss:3.0439
# 1/1 [==============================] - 0s 17ms/step
# epoch:62  d_loss:0.7012  g_loss:2.1523
# 1/1 [==============================] - 0s 18ms/step
# epoch:63  d_loss:0.5587  g_loss:1.9167
# 1/1 [==============================] - 0s 20ms/step
# epoch:64  d_loss:0.7245  g_loss:2.0674
# 1/1 [==============================] - 0s 19ms/step
# epoch:65  d_loss:0.4507  g_loss:3.0996
# 1/1 [==============================] - 0s 18ms/step
# epoch:66  d_loss:0.4715  g_loss:2.9814
# 1/1 [==============================] - 0s 18ms/step
# epoch:67  d_loss:0.4803  g_loss:2.3177
# 1/1 [==============================] - 0s 17ms/step
# epoch:68  d_loss:0.4863  g_loss:1.9340
# 1/1 [==============================] - 0s 16ms/step
# epoch:69  d_loss:0.4202  g_loss:2.0283
# 1/1 [==============================] - 0s 18ms/step
# epoch:70  d_loss:0.3347  g_loss:2.5723
# 1/1 [==============================] - 0s 18ms/step
# epoch:71  d_loss:0.3403  g_loss:2.4034
# 1/1 [==============================] - 0s 23ms/step
# epoch:72  d_loss:0.3173  g_loss:1.9591
# 1/1 [==============================] - 0s 18ms/step
# epoch:73  d_loss:0.2342  g_loss:1.6430
# 1/1 [==============================] - 0s 16ms/step
# epoch:74  d_loss:0.3350  g_loss:1.6190
# 1/1 [==============================] - 0s 19ms/step
# epoch:75  d_loss:0.2961  g_loss:1.6517
# 1/1 [==============================] - 0s 19ms/step
# epoch:76  d_loss:0.2179  g_loss:1.5763
# 1/1 [==============================] - 0s 19ms/step
# epoch:77  d_loss:0.5527  g_loss:1.0485
# 1/1 [==============================] - 0s 17ms/step
# epoch:78  d_loss:0.4995  g_loss:0.7409
# 1/1 [==============================] - 0s 18ms/step
# epoch:79  d_loss:0.5068  g_loss:1.0852
# 1/1 [==============================] - 0s 22ms/step
# epoch:80  d_loss:0.6351  g_loss:1.0266
# 1/1 [==============================] - 0s 22ms/step
# epoch:81  d_loss:0.7064  g_loss:0.5703
# 1/1 [==============================] - 0s 19ms/step
# epoch:82  d_loss:0.9396  g_loss:0.4871
# 1/1 [==============================] - 0s 19ms/step
# epoch:83  d_loss:0.6873  g_loss:0.7018
# 1/1 [==============================] - 0s 18ms/step
# epoch:84  d_loss:0.7714  g_loss:0.7889
# 1/1 [==============================] - 0s 17ms/step
# epoch:85  d_loss:0.5786  g_loss:1.1820
# 1/1 [==============================] - 0s 16ms/step
# epoch:86  d_loss:0.4272  g_loss:1.4618
# 1/1 [==============================] - 0s 18ms/step
# epoch:87  d_loss:0.3471  g_loss:1.5907
# 1/1 [==============================] - 0s 19ms/step
# epoch:88  d_loss:0.2258  g_loss:2.0057
# 1/1 [==============================] - 0s 18ms/step
# epoch:89  d_loss:0.1730  g_loss:2.4101
# 1/1 [==============================] - 0s 19ms/step
# epoch:90  d_loss:0.1273  g_loss:2.6432
# 1/1 [==============================] - 0s 18ms/step
# epoch:91  d_loss:0.1553  g_loss:2.7370
# 1/1 [==============================] - 0s 16ms/step
# epoch:92  d_loss:0.1953  g_loss:2.8931
# 1/1 [==============================] - 0s 30ms/step
# epoch:93  d_loss:0.3982  g_loss:2.2873
# 1/1 [==============================] - 0s 17ms/step
# epoch:94  d_loss:0.5558  g_loss:2.5778
# 1/1 [==============================] - 0s 20ms/step
# epoch:95  d_loss:0.7377  g_loss:3.2336
# 1/1 [==============================] - 0s 16ms/step
# epoch:96  d_loss:0.9756  g_loss:3.1713
# 1/1 [==============================] - 0s 19ms/step
# epoch:97  d_loss:0.8143  g_loss:2.5475
# 1/1 [==============================] - 0s 18ms/step
# epoch:98  d_loss:1.4596  g_loss:1.6810
# 1/1 [==============================] - 0s 18ms/step
# epoch:99  d_loss:1.0408  g_loss:1.4272
# 1/1 [==============================] - 0s 21ms/step
# epoch:100  d_loss:1.0264  g_loss:1.6175
# 1/1 [==============================] - 0s 18ms/step
# epoch:101  d_loss:0.8920  g_loss:1.5926
# 1/1 [==============================] - 0s 19ms/step
# epoch:102  d_loss:0.7409  g_loss:1.5991
# 1/1 [==============================] - 0s 19ms/step
# epoch:103  d_loss:0.8202  g_loss:1.1954
# 1/1 [==============================] - 0s 19ms/step
# epoch:104  d_loss:0.7059  g_loss:1.3507
# 1/1 [==============================] - 0s 21ms/step
# epoch:105  d_loss:0.6805  g_loss:1.3169
# 1/1 [==============================] - 0s 17ms/step
# epoch:106  d_loss:0.5448  g_loss:1.4063
# 1/1 [==============================] - 0s 21ms/step
# epoch:107  d_loss:0.4932  g_loss:1.4758
# 1/1 [==============================] - 0s 20ms/step
# epoch:108  d_loss:0.4380  g_loss:1.6670
# 1/1 [==============================] - 0s 18ms/step
# epoch:109  d_loss:0.5484  g_loss:1.6689
# 1/1 [==============================] - 0s 18ms/step
# epoch:110  d_loss:0.3510  g_loss:1.5755
# 1/1 [==============================] - 0s 16ms/step
# epoch:111  d_loss:0.5034  g_loss:1.4875
# 1/1 [==============================] - 0s 21ms/step
# epoch:112  d_loss:0.4340  g_loss:1.3474
# 1/1 [==============================] - 0s 18ms/step
# epoch:113  d_loss:0.3967  g_loss:1.5087
# 1/1 [==============================] - 0s 19ms/step
# epoch:114  d_loss:0.5190  g_loss:1.5971
# 1/1 [==============================] - 0s 20ms/step
# epoch:115  d_loss:0.3274  g_loss:1.6084
# 1/1 [==============================] - 0s 19ms/step
# epoch:116  d_loss:0.3064  g_loss:1.6130
# 1/1 [==============================] - 0s 20ms/step
# epoch:117  d_loss:0.3592  g_loss:1.6160
# 1/1 [==============================] - 0s 18ms/step
# epoch:118  d_loss:0.4005  g_loss:1.4865
# 1/1 [==============================] - 0s 24ms/step
# epoch:119  d_loss:0.4774  g_loss:1.3957
# 1/1 [==============================] - 0s 19ms/step
# epoch:120  d_loss:0.3062  g_loss:1.5603
# 1/1 [==============================] - 0s 16ms/step
# epoch:121  d_loss:0.4883  g_loss:1.4868
# 1/1 [==============================] - 0s 17ms/step
# epoch:122  d_loss:0.3973  g_loss:1.3771
# 1/1 [==============================] - 0s 18ms/step
# epoch:123  d_loss:0.5799  g_loss:1.3645
# 1/1 [==============================] - 0s 18ms/step
# epoch:124  d_loss:0.4637  g_loss:1.2353
# 1/1 [==============================] - 0s 16ms/step
# epoch:125  d_loss:0.4685  g_loss:1.2043
# 1/1 [==============================] - 0s 23ms/step
# epoch:126  d_loss:0.4551  g_loss:1.3579
# 1/1 [==============================] - 0s 22ms/step
# epoch:127  d_loss:0.4145  g_loss:1.2016
# 1/1 [==============================] - 0s 18ms/step
# epoch:128  d_loss:0.5665  g_loss:0.8974
# 1/1 [==============================] - 0s 18ms/step
# epoch:129  d_loss:0.5450  g_loss:0.8042
# 1/1 [==============================] - 0s 19ms/step
# epoch:130  d_loss:0.6493  g_loss:0.7265
# 1/1 [==============================] - 0s 21ms/step
# epoch:131  d_loss:0.5227  g_loss:1.0647
# 1/1 [==============================] - 0s 18ms/step
# epoch:132  d_loss:0.5326  g_loss:1.2892
# 1/1 [==============================] - 0s 17ms/step
# epoch:133  d_loss:0.6234  g_loss:1.1568
# 1/1 [==============================] - 0s 17ms/step
# epoch:134  d_loss:0.8223  g_loss:1.0067
# 1/1 [==============================] - 0s 22ms/step
# epoch:135  d_loss:0.5676  g_loss:0.9454
# 1/1 [==============================] - 0s 20ms/step
# epoch:136  d_loss:0.4693  g_loss:1.1549
# 1/1 [==============================] - 0s 20ms/step
# epoch:137  d_loss:0.3658  g_loss:1.5675
# 1/1 [==============================] - 0s 19ms/step
# epoch:138  d_loss:0.3731  g_loss:1.8399
# 1/1 [==============================] - 0s 18ms/step
# epoch:139  d_loss:0.3988  g_loss:1.9081
# 1/1 [==============================] - 0s 17ms/step
# epoch:140  d_loss:0.4296  g_loss:1.9721
# 1/1 [==============================] - 0s 17ms/step
# epoch:141  d_loss:0.2393  g_loss:1.8916
# 1/1 [==============================] - 0s 26ms/step
# epoch:142  d_loss:0.2409  g_loss:2.0197
# 1/1 [==============================] - 0s 19ms/step
# epoch:143  d_loss:0.2585  g_loss:2.5766
# 1/1 [==============================] - 0s 17ms/step
# epoch:144  d_loss:0.2629  g_loss:3.2839
# 1/1 [==============================] - 0s 16ms/step
# epoch:145  d_loss:0.3045  g_loss:3.1942
# 1/1 [==============================] - 0s 19ms/step
# epoch:146  d_loss:0.5694  g_loss:2.1748
# 1/1 [==============================] - 0s 20ms/step
# epoch:147  d_loss:0.3624  g_loss:2.2145
# 1/1 [==============================] - 0s 18ms/step
# epoch:148  d_loss:0.5045  g_loss:3.1033
# 1/1 [==============================] - 0s 18ms/step
# epoch:149  d_loss:0.5613  g_loss:3.7557
# 1/1 [==============================] - 0s 21ms/step
# epoch:150  d_loss:0.6591  g_loss:3.4912
# 1/1 [==============================] - 0s 21ms/step
# epoch:151  d_loss:0.7108  g_loss:2.8984
# 1/1 [==============================] - 0s 22ms/step
# epoch:152  d_loss:0.7586  g_loss:2.3025
# 1/1 [==============================] - 0s 16ms/step
# epoch:153  d_loss:0.9448  g_loss:2.4047
# 1/1 [==============================] - 0s 17ms/step
# epoch:154  d_loss:1.3169  g_loss:1.6836
# 1/1 [==============================] - 0s 16ms/step
# epoch:155  d_loss:0.9314  g_loss:2.4842
# 1/1 [==============================] - 0s 17ms/step
# epoch:156  d_loss:0.8936  g_loss:1.8909
# 1/1 [==============================] - 0s 19ms/step
# epoch:157  d_loss:0.9297  g_loss:2.1533
# 1/1 [==============================] - 0s 17ms/step
# epoch:158  d_loss:0.7817  g_loss:1.8972
# 1/1 [==============================] - 0s 16ms/step
# epoch:159  d_loss:0.5625  g_loss:1.6745
# 1/1 [==============================] - 0s 17ms/step
# epoch:160  d_loss:0.5508  g_loss:1.5451
# 1/1 [==============================] - 0s 32ms/step
# epoch:161  d_loss:0.4477  g_loss:1.7524
# 1/1 [==============================] - 0s 31ms/step
# epoch:162  d_loss:0.5438  g_loss:1.6270
# 1/1 [==============================] - 0s 28ms/step
# epoch:163  d_loss:0.4524  g_loss:1.5905
# 1/1 [==============================] - 0s 26ms/step
# epoch:164  d_loss:0.5082  g_loss:1.7020
# 1/1 [==============================] - 0s 26ms/step
# epoch:165  d_loss:0.4967  g_loss:1.5999
# 1/1 [==============================] - 0s 28ms/step
# epoch:166  d_loss:0.3851  g_loss:1.7474
# 1/1 [==============================] - 0s 25ms/step
# epoch:167  d_loss:0.3627  g_loss:1.8043
# 1/1 [==============================] - 0s 26ms/step
# epoch:168  d_loss:0.3654  g_loss:1.6627
# 1/1 [==============================] - 0s 33ms/step
# epoch:169  d_loss:0.4306  g_loss:1.7557
# 1/1 [==============================] - 0s 25ms/step
# epoch:170  d_loss:0.3777  g_loss:1.5425
# 1/1 [==============================] - 0s 26ms/step
# epoch:171  d_loss:0.4579  g_loss:1.4380
# 1/1 [==============================] - 0s 24ms/step
# epoch:172  d_loss:0.3108  g_loss:1.5855
# 1/1 [==============================] - 0s 30ms/step
# epoch:173  d_loss:0.3365  g_loss:1.5498
# 1/1 [==============================] - 0s 34ms/step
# epoch:174  d_loss:0.3779  g_loss:1.5190
# 1/1 [==============================] - 0s 30ms/step
# epoch:175  d_loss:0.3308  g_loss:1.8246
# 1/1 [==============================] - 0s 25ms/step
# epoch:176  d_loss:0.2702  g_loss:1.7478
# 1/1 [==============================] - 0s 30ms/step
# epoch:177  d_loss:0.3273  g_loss:1.9928
# 1/1 [==============================] - 0s 25ms/step
# epoch:178  d_loss:0.3118  g_loss:1.7681
# 1/1 [==============================] - 0s 18ms/step
# epoch:179  d_loss:0.3572  g_loss:1.5095
# 1/1 [==============================] - 0s 17ms/step
# epoch:180  d_loss:0.4835  g_loss:1.3131
# 1/1 [==============================] - 0s 19ms/step
# epoch:181  d_loss:0.3474  g_loss:1.4270
# 1/1 [==============================] - 0s 17ms/step
# epoch:182  d_loss:0.4260  g_loss:1.5392
# 1/1 [==============================] - 0s 18ms/step
# epoch:183  d_loss:0.6132  g_loss:1.3334
# 1/1 [==============================] - 0s 17ms/step
# epoch:184  d_loss:0.5027  g_loss:1.3092
# 1/1 [==============================] - 0s 17ms/step
# epoch:185  d_loss:0.3916  g_loss:1.2268
# 1/1 [==============================] - 0s 18ms/step
# epoch:186  d_loss:0.5531  g_loss:1.4340
# 1/1 [==============================] - 0s 17ms/step
# epoch:187  d_loss:0.4473  g_loss:1.4164
# 1/1 [==============================] - 0s 17ms/step
# epoch:188  d_loss:0.4609  g_loss:1.2344
# 1/1 [==============================] - 0s 18ms/step
# epoch:189  d_loss:0.4843  g_loss:1.3395
# 1/1 [==============================] - 0s 16ms/step
# epoch:190  d_loss:0.6233  g_loss:1.1119
# 1/1 [==============================] - 0s 18ms/step
# epoch:191  d_loss:0.5463  g_loss:0.9334
# 1/1 [==============================] - 0s 22ms/step
# epoch:192  d_loss:0.5091  g_loss:1.1376
# 1/1 [==============================] - 0s 19ms/step
# epoch:193  d_loss:0.5509  g_loss:1.3715
# 1/1 [==============================] - 0s 22ms/step
# epoch:194  d_loss:0.5432  g_loss:1.3930
# 1/1 [==============================] - 0s 17ms/step
# epoch:195  d_loss:0.6080  g_loss:1.1640
# 1/1 [==============================] - 0s 17ms/step
# epoch:196  d_loss:0.5254  g_loss:1.1984
# 1/1 [==============================] - 0s 18ms/step
# epoch:197  d_loss:0.5890  g_loss:1.1358
# 1/1 [==============================] - 0s 17ms/step
# epoch:198  d_loss:0.6544  g_loss:1.1936
# 1/1 [==============================] - 0s 20ms/step
# epoch:199  d_loss:0.5338  g_loss:1.3507
# 1/1 [==============================] - 0s 19ms/step
# epoch:200  d_loss:0.6448  g_loss:1.2326
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# epoch:201  d_loss:0.5221  g_loss:1.2681
# 1/1 [==============================] - 0s 21ms/step
# epoch:202  d_loss:0.5190  g_loss:1.3810
# 1/1 [==============================] - 0s 20ms/step
# epoch:203  d_loss:0.4665  g_loss:1.5087
# 1/1 [==============================] - 0s 22ms/step
# epoch:204  d_loss:0.3753  g_loss:1.5585
# 1/1 [==============================] - 0s 21ms/step
# epoch:205  d_loss:0.3560  g_loss:1.9397
# 1/1 [==============================] - 0s 21ms/step
# epoch:206  d_loss:0.3888  g_loss:1.7610
# 1/1 [==============================] - 0s 19ms/step
# epoch:207  d_loss:0.3187  g_loss:2.0481
# 1/1 [==============================] - 0s 18ms/step
# epoch:208  d_loss:0.3886  g_loss:2.3017
# 1/1 [==============================] - 0s 17ms/step
# epoch:209  d_loss:0.3211  g_loss:1.8904
# 1/1 [==============================] - 0s 22ms/step
# epoch:210  d_loss:0.2608  g_loss:2.1302
# 1/1 [==============================] - 0s 23ms/step
# epoch:211  d_loss:0.2228  g_loss:2.5134
# 1/1 [==============================] - 0s 20ms/step
# epoch:212  d_loss:0.3535  g_loss:2.6460
# 1/1 [==============================] - 0s 21ms/step
# epoch:213  d_loss:0.2434  g_loss:2.5306
# 1/1 [==============================] - 0s 18ms/step
# epoch:214  d_loss:0.3122  g_loss:3.0193
# 1/1 [==============================] - 0s 17ms/step
# epoch:215  d_loss:0.3304  g_loss:2.1399
# 1/1 [==============================] - 0s 20ms/step
# epoch:216  d_loss:0.3688  g_loss:2.3245
# 1/1 [==============================] - 0s 17ms/step
# epoch:217  d_loss:0.5020  g_loss:2.1884
# 1/1 [==============================] - 0s 18ms/step
# epoch:218  d_loss:0.3540  g_loss:2.6545
# 1/1 [==============================] - 0s 17ms/step
# epoch:219  d_loss:0.6498  g_loss:2.3586
# 1/1 [==============================] - 0s 20ms/step
# epoch:220  d_loss:0.6485  g_loss:1.7758
# 1/1 [==============================] - 0s 18ms/step
# epoch:221  d_loss:0.6073  g_loss:1.7714
# 1/1 [==============================] - 0s 19ms/step
# epoch:222  d_loss:0.5602  g_loss:1.7386
# 1/1 [==============================] - 0s 18ms/step
# epoch:223  d_loss:0.4797  g_loss:2.0986
# 1/1 [==============================] - 0s 18ms/step
# epoch:224  d_loss:0.8813  g_loss:1.7396
# 1/1 [==============================] - 0s 19ms/step
# epoch:225  d_loss:0.6609  g_loss:1.5859
# 1/1 [==============================] - 0s 19ms/step
# epoch:226  d_loss:0.8262  g_loss:1.4823
# 1/1 [==============================] - 0s 18ms/step
# epoch:227  d_loss:0.6754  g_loss:1.2710
# 1/1 [==============================] - 0s 20ms/step
# epoch:228  d_loss:0.6922  g_loss:1.3723
# 1/1 [==============================] - 0s 19ms/step
# epoch:229  d_loss:0.5704  g_loss:1.5678
# 1/1 [==============================] - 0s 26ms/step
# epoch:230  d_loss:0.4984  g_loss:1.8824
# 1/1 [==============================] - 0s 19ms/step
# epoch:231  d_loss:0.5419  g_loss:1.4938
# 1/1 [==============================] - 0s 17ms/step
# epoch:232  d_loss:0.5764  g_loss:1.3608
# 1/1 [==============================] - 0s 19ms/step
# epoch:233  d_loss:0.5201  g_loss:1.4524
# 1/1 [==============================] - 0s 21ms/step
# epoch:234  d_loss:0.5888  g_loss:1.6333
# 1/1 [==============================] - 0s 16ms/step
# epoch:235  d_loss:0.5917  g_loss:1.6672
# 1/1 [==============================] - 0s 19ms/step
# epoch:236  d_loss:0.5724  g_loss:1.2617
# 1/1 [==============================] - 0s 18ms/step
# epoch:237  d_loss:0.4695  g_loss:1.5169
# 1/1 [==============================] - 0s 19ms/step
# epoch:238  d_loss:0.4471  g_loss:1.4535
# 1/1 [==============================] - 0s 17ms/step
# epoch:239  d_loss:0.4229  g_loss:1.4200
# 1/1 [==============================] - 0s 18ms/step
# epoch:240  d_loss:0.4087  g_loss:1.7089
# 1/1 [==============================] - 0s 19ms/step
# epoch:241  d_loss:0.3906  g_loss:1.7900
# 1/1 [==============================] - 0s 18ms/step
# epoch:242  d_loss:0.3634  g_loss:1.7481
# 1/1 [==============================] - 0s 19ms/step
# epoch:243  d_loss:0.3181  g_loss:2.2244
# 1/1 [==============================] - 0s 19ms/step
# epoch:244  d_loss:0.3942  g_loss:1.9952
# 1/1 [==============================] - 0s 24ms/step
# epoch:245  d_loss:0.4021  g_loss:1.7274
# 1/1 [==============================] - 0s 20ms/step
# epoch:246  d_loss:0.4624  g_loss:1.6396
# 1/1 [==============================] - 0s 21ms/step
# epoch:247  d_loss:0.3372  g_loss:1.8359
# 1/1 [==============================] - 0s 19ms/step
# epoch:248  d_loss:0.3118  g_loss:1.8323
# 1/1 [==============================] - 0s 19ms/step
# epoch:249  d_loss:0.4151  g_loss:1.7908
# 1/1 [==============================] - 0s 19ms/step
# epoch:250  d_loss:0.4386  g_loss:1.6476
# 1/1 [==============================] - 0s 17ms/step
# epoch:251  d_loss:0.3244  g_loss:1.8635
# 1/1 [==============================] - 0s 19ms/step
# epoch:252  d_loss:0.5355  g_loss:1.6031
# 1/1 [==============================] - 0s 17ms/step
# epoch:253  d_loss:0.3636  g_loss:1.8109
# 1/1 [==============================] - 0s 18ms/step
# epoch:254  d_loss:0.4539  g_loss:1.7546
# 1/1 [==============================] - 0s 17ms/step
# epoch:255  d_loss:0.4658  g_loss:1.5711
# 1/1 [==============================] - 0s 20ms/step
# epoch:256  d_loss:0.4690  g_loss:1.8196
# 1/1 [==============================] - 0s 20ms/step
# epoch:257  d_loss:0.3984  g_loss:2.0155
# 1/1 [==============================] - 0s 18ms/step
# epoch:258  d_loss:0.4895  g_loss:1.4994
# 1/1 [==============================] - 0s 22ms/step
# epoch:259  d_loss:0.4197  g_loss:1.7951
# 1/1 [==============================] - 0s 20ms/step
# epoch:260  d_loss:0.4007  g_loss:1.9051
# 1/1 [==============================] - 0s 21ms/step
# epoch:261  d_loss:0.4051  g_loss:1.8192
# 1/1 [==============================] - 0s 18ms/step
# epoch:262  d_loss:0.4447  g_loss:1.7995
# 1/1 [==============================] - 0s 18ms/step
# epoch:263  d_loss:0.5932  g_loss:1.4039
# 1/1 [==============================] - 0s 18ms/step
# epoch:264  d_loss:0.4696  g_loss:1.6605
# 1/1 [==============================] - 0s 17ms/step
# epoch:265  d_loss:0.5367  g_loss:1.4381
# 1/1 [==============================] - 0s 20ms/step
# epoch:266  d_loss:0.4826  g_loss:1.5589
# 1/1 [==============================] - 0s 19ms/step
# epoch:267  d_loss:0.5547  g_loss:1.5645
# 1/1 [==============================] - 0s 26ms/step
# epoch:268  d_loss:0.3426  g_loss:1.8592
# 1/1 [==============================] - 0s 20ms/step
# epoch:269  d_loss:0.5557  g_loss:1.6516
# 1/1 [==============================] - 0s 19ms/step
# epoch:270  d_loss:0.5792  g_loss:1.8142
# 1/1 [==============================] - 0s 19ms/step
# epoch:271  d_loss:0.4762  g_loss:1.6501
# 1/1 [==============================] - 0s 19ms/step
# epoch:272  d_loss:0.4461  g_loss:2.0743
# 1/1 [==============================] - 0s 20ms/step
# epoch:273  d_loss:0.4855  g_loss:1.8890
# 1/1 [==============================] - 0s 21ms/step
# epoch:274  d_loss:0.3522  g_loss:1.8824
# 1/1 [==============================] - 0s 22ms/step
# epoch:275  d_loss:0.4085  g_loss:1.9044
# 1/1 [==============================] - 0s 17ms/step
# epoch:276  d_loss:0.3756  g_loss:1.8146
# 1/1 [==============================] - 0s 18ms/step
# epoch:277  d_loss:0.3679  g_loss:2.1042
# 1/1 [==============================] - 0s 17ms/step
# epoch:278  d_loss:0.3158  g_loss:2.3497
# 1/1 [==============================] - 0s 19ms/step
# epoch:279  d_loss:0.4423  g_loss:2.7470
# 1/1 [==============================] - 0s 18ms/step
# epoch:280  d_loss:0.3926  g_loss:2.0309
# 1/1 [==============================] - 0s 19ms/step
# epoch:281  d_loss:0.3725  g_loss:2.2127
# 1/1 [==============================] - 0s 22ms/step
# epoch:282  d_loss:0.4293  g_loss:2.3497
# 1/1 [==============================] - 0s 20ms/step
# epoch:283  d_loss:0.6079  g_loss:2.1599
# 1/1 [==============================] - 0s 18ms/step
# epoch:284  d_loss:0.4816  g_loss:2.4760
# 1/1 [==============================] - 0s 17ms/step
# epoch:285  d_loss:0.4805  g_loss:2.2892
# 1/1 [==============================] - 0s 27ms/step
# epoch:286  d_loss:0.6804  g_loss:2.2875
# 1/1 [==============================] - 0s 29ms/step
# epoch:287  d_loss:0.5577  g_loss:1.6979
# 1/1 [==============================] - 0s 28ms/step
# epoch:288  d_loss:0.6091  g_loss:1.9116
# 1/1 [==============================] - 0s 25ms/step
# epoch:289  d_loss:0.6949  g_loss:2.2051
# 1/1 [==============================] - 0s 32ms/step
# epoch:290  d_loss:0.6380  g_loss:2.0575
# 1/1 [==============================] - 0s 33ms/step
# epoch:291  d_loss:0.7455  g_loss:1.6121
# 1/1 [==============================] - 0s 28ms/step
# epoch:292  d_loss:0.7405  g_loss:1.4003
# 1/1 [==============================] - 0s 25ms/step
# epoch:293  d_loss:0.7060  g_loss:1.4428
# 1/1 [==============================] - 0s 29ms/step
# epoch:294  d_loss:0.6121  g_loss:1.4891
# 1/1 [==============================] - 0s 30ms/step
# epoch:295  d_loss:0.6147  g_loss:1.5942
# 1/1 [==============================] - 0s 34ms/step
# epoch:296  d_loss:0.6130  g_loss:1.7475
# 1/1 [==============================] - 0s 27ms/step
# epoch:297  d_loss:0.4568  g_loss:1.8471
# 1/1 [==============================] - 0s 34ms/step
# epoch:298  d_loss:0.5567  g_loss:1.7081
# 1/1 [==============================] - 0s 26ms/step
# epoch:299  d_loss:0.5998  g_loss:1.3057
# 1/1 [==============================] - 0s 28ms/step
# epoch:300  d_loss:0.5648  g_loss:1.3945
# 1/1 [==============================] - 0s 29ms/step
# epoch:301  d_loss:0.3814  g_loss:1.5105
# 1/1 [==============================] - 0s 32ms/step
# epoch:302  d_loss:0.4446  g_loss:1.5206
# 1/1 [==============================] - 0s 29ms/step
# epoch:303  d_loss:0.4108  g_loss:1.9872
# 1/1 [==============================] - 0s 16ms/step
# epoch:304  d_loss:0.4515  g_loss:1.9015
# 1/1 [==============================] - 0s 16ms/step
# epoch:305  d_loss:0.3555  g_loss:2.2963
# 1/1 [==============================] - 0s 17ms/step
# epoch:306  d_loss:0.3451  g_loss:2.1167
# 1/1 [==============================] - 0s 19ms/step
# epoch:307  d_loss:0.3870  g_loss:2.1560
# 1/1 [==============================] - 0s 19ms/step
# epoch:308  d_loss:0.3086  g_loss:2.2224
# 1/1 [==============================] - 0s 17ms/step
# epoch:309  d_loss:0.4075  g_loss:1.9407
# 1/1 [==============================] - 0s 28ms/step
# epoch:310  d_loss:0.3530  g_loss:2.1469
# 1/1 [==============================] - 0s 19ms/step
# epoch:311  d_loss:0.4283  g_loss:1.9577
# 1/1 [==============================] - 0s 20ms/step
# epoch:312  d_loss:0.2919  g_loss:2.1658
# 1/1 [==============================] - 0s 17ms/step
# epoch:313  d_loss:0.3563  g_loss:1.9156
# 1/1 [==============================] - 0s 16ms/step
# epoch:314  d_loss:0.2490  g_loss:1.9165
# 1/1 [==============================] - 0s 22ms/step
# epoch:315  d_loss:0.3137  g_loss:1.8383
# 1/1 [==============================] - 0s 19ms/step
# epoch:316  d_loss:0.2842  g_loss:2.4101
# 1/1 [==============================] - 0s 20ms/step
# epoch:317  d_loss:0.2231  g_loss:2.4317
# 1/1 [==============================] - 0s 17ms/step
# epoch:318  d_loss:0.2916  g_loss:2.7843
# 1/1 [==============================] - 0s 24ms/step
# epoch:319  d_loss:0.3634  g_loss:2.2972
# 1/1 [==============================] - 0s 17ms/step
# epoch:320  d_loss:0.5774  g_loss:1.6179
# 1/1 [==============================] - 0s 16ms/step
# epoch:321  d_loss:0.4523  g_loss:1.9271
# 1/1 [==============================] - 0s 18ms/step
# epoch:322  d_loss:0.5694  g_loss:2.1680
# 1/1 [==============================] - 0s 19ms/step
# epoch:323  d_loss:0.4661  g_loss:1.9926
# 1/1 [==============================] - 0s 20ms/step
# epoch:324  d_loss:0.4363  g_loss:2.1009
# 1/1 [==============================] - 0s 16ms/step
# epoch:325  d_loss:0.4840  g_loss:2.1624
# 1/1 [==============================] - 0s 17ms/step
# epoch:326  d_loss:0.6219  g_loss:1.9564
# 1/1 [==============================] - 0s 21ms/step
# epoch:327  d_loss:0.4565  g_loss:2.1923
# 1/1 [==============================] - 0s 16ms/step
# epoch:328  d_loss:0.4203  g_loss:1.4997
# 1/1 [==============================] - 0s 17ms/step
# epoch:329  d_loss:0.5498  g_loss:1.4158
# 1/1 [==============================] - 0s 19ms/step
# epoch:330  d_loss:0.4440  g_loss:1.6248
# 1/1 [==============================] - 0s 16ms/step
# epoch:331  d_loss:0.5797  g_loss:1.7806
# 1/1 [==============================] - 0s 16ms/step
# epoch:332  d_loss:0.4632  g_loss:1.7319
# 1/1 [==============================] - 0s 20ms/step
# epoch:333  d_loss:0.3788  g_loss:2.3270
# 1/1 [==============================] - 0s 20ms/step
# epoch:334  d_loss:0.4666  g_loss:2.0874
# 1/1 [==============================] - 0s 21ms/step
# epoch:335  d_loss:0.5178  g_loss:1.9753
# 1/1 [==============================] - 0s 19ms/step
# epoch:336  d_loss:0.4799  g_loss:1.8692
# 1/1 [==============================] - 0s 18ms/step
# epoch:337  d_loss:0.5831  g_loss:1.5038
# 1/1 [==============================] - 0s 17ms/step
# epoch:338  d_loss:0.6615  g_loss:1.7741
# 1/1 [==============================] - 0s 18ms/step
# epoch:339  d_loss:0.5540  g_loss:1.6497
# 1/1 [==============================] - 0s 19ms/step
# epoch:340  d_loss:0.4208  g_loss:2.2463
# 1/1 [==============================] - 0s 21ms/step
# epoch:341  d_loss:0.4069  g_loss:2.1804
# 1/1 [==============================] - 0s 17ms/step
# epoch:342  d_loss:0.4750  g_loss:2.1537
# 1/1 [==============================] - 0s 17ms/step
# epoch:343  d_loss:0.3509  g_loss:1.9882
# 1/1 [==============================] - 0s 16ms/step
# epoch:344  d_loss:0.4950  g_loss:1.7544
# 1/1 [==============================] - 0s 17ms/step
# epoch:345  d_loss:0.5157  g_loss:1.2087
# 1/1 [==============================] - 0s 18ms/step
# epoch:346  d_loss:0.5204  g_loss:1.4080
# 1/1 [==============================] - 0s 18ms/step
# epoch:347  d_loss:0.4072  g_loss:1.8214
# 1/1 [==============================] - 0s 21ms/step
# epoch:348  d_loss:0.3797  g_loss:2.1353
# 1/1 [==============================] - 0s 22ms/step
# epoch:349  d_loss:0.3450  g_loss:2.2664
# 1/1 [==============================] - 0s 19ms/step
# epoch:350  d_loss:0.5207  g_loss:1.8322
# 1/1 [==============================] - 0s 16ms/step
# epoch:351  d_loss:0.5172  g_loss:1.6377
# 1/1 [==============================] - 0s 16ms/step
# epoch:352  d_loss:0.5258  g_loss:1.6475
# 1/1 [==============================] - 0s 18ms/step
# epoch:353  d_loss:0.4107  g_loss:1.8498
# 1/1 [==============================] - 0s 21ms/step
# epoch:354  d_loss:0.3011  g_loss:2.0232
# 1/1 [==============================] - 0s 19ms/step
# epoch:355  d_loss:0.4204  g_loss:1.8577
# 1/1 [==============================] - 0s 21ms/step
# epoch:356  d_loss:0.4071  g_loss:2.0721
# 1/1 [==============================] - 0s 19ms/step
# epoch:357  d_loss:0.3436  g_loss:1.9895
# 1/1 [==============================] - 0s 18ms/step
# epoch:358  d_loss:0.3101  g_loss:1.9617
# 1/1 [==============================] - 0s 18ms/step
# epoch:359  d_loss:0.4999  g_loss:1.6528
# 1/1 [==============================] - 0s 19ms/step
# epoch:360  d_loss:0.3613  g_loss:1.8253
# 1/1 [==============================] - 0s 18ms/step
# epoch:361  d_loss:0.4597  g_loss:1.9043
# 1/1 [==============================] - 0s 18ms/step
# epoch:362  d_loss:0.3377  g_loss:1.9657
# 1/1 [==============================] - 0s 17ms/step
# epoch:363  d_loss:0.3374  g_loss:1.6801
# 1/1 [==============================] - 0s 17ms/step
# epoch:364  d_loss:0.5009  g_loss:1.7189
# 1/1 [==============================] - 0s 23ms/step
# epoch:365  d_loss:0.3309  g_loss:2.0362
# 1/1 [==============================] - 0s 18ms/step
# epoch:366  d_loss:0.4190  g_loss:1.8703
# 1/1 [==============================] - 0s 18ms/step
# epoch:367  d_loss:0.4181  g_loss:1.7890
# 1/1 [==============================] - 0s 17ms/step
# epoch:368  d_loss:0.4441  g_loss:1.7860
# 1/1 [==============================] - 0s 16ms/step
# epoch:369  d_loss:0.4866  g_loss:1.8912
# 1/1 [==============================] - 0s 19ms/step
# epoch:370  d_loss:0.4121  g_loss:1.6424
# 1/1 [==============================] - 0s 18ms/step
# epoch:371  d_loss:0.3936  g_loss:1.6367
# 1/1 [==============================] - 0s 19ms/step
# epoch:372  d_loss:0.4732  g_loss:1.9317
# 1/1 [==============================] - 0s 16ms/step
# epoch:373  d_loss:0.3385  g_loss:1.5845
# 1/1 [==============================] - 0s 19ms/step
# epoch:374  d_loss:0.5726  g_loss:2.0686
# 1/1 [==============================] - 0s 17ms/step
# epoch:375  d_loss:0.4869  g_loss:1.8212
# 1/1 [==============================] - 0s 17ms/step
# epoch:376  d_loss:0.5086  g_loss:1.7816
# 1/1 [==============================] - 0s 19ms/step
# epoch:377  d_loss:0.5396  g_loss:1.4482
# 1/1 [==============================] - 0s 17ms/step
# epoch:378  d_loss:0.5328  g_loss:1.6973
# 1/1 [==============================] - 0s 17ms/step
# epoch:379  d_loss:0.2988  g_loss:2.0669
# 1/1 [==============================] - 0s 21ms/step
# epoch:380  d_loss:0.5185  g_loss:1.6445
# 1/1 [==============================] - 0s 19ms/step
# epoch:381  d_loss:0.4696  g_loss:1.7925
# 1/1 [==============================] - 0s 19ms/step
# epoch:382  d_loss:0.5068  g_loss:1.6998
# 1/1 [==============================] - 0s 17ms/step
# epoch:383  d_loss:0.5155  g_loss:1.6744
# 1/1 [==============================] - 0s 20ms/step
# epoch:384  d_loss:0.4929  g_loss:1.3452
# 1/1 [==============================] - 0s 18ms/step
# epoch:385  d_loss:0.3261  g_loss:1.7167
# 1/1 [==============================] - 0s 18ms/step
# epoch:386  d_loss:0.3858  g_loss:2.0444
# 1/1 [==============================] - 0s 16ms/step
# epoch:387  d_loss:0.3936  g_loss:2.0943
# 1/1 [==============================] - 0s 20ms/step
# epoch:388  d_loss:0.3717  g_loss:2.0544
# 1/1 [==============================] - 0s 17ms/step
# epoch:389  d_loss:0.4479  g_loss:2.0393
# 1/1 [==============================] - 0s 18ms/step
# epoch:390  d_loss:0.3949  g_loss:2.0362
# 1/1 [==============================] - 0s 17ms/step
# epoch:391  d_loss:0.3878  g_loss:1.9159
# 1/1 [==============================] - 0s 16ms/step
# epoch:392  d_loss:0.3462  g_loss:2.2102
# 1/1 [==============================] - 0s 16ms/step
# epoch:393  d_loss:0.3010  g_loss:2.3273
# 1/1 [==============================] - 0s 19ms/step
# epoch:394  d_loss:0.2760  g_loss:2.5394
# 1/1 [==============================] - 0s 18ms/step
# epoch:395  d_loss:0.2205  g_loss:2.4462
# 1/1 [==============================] - 0s 19ms/step
# epoch:396  d_loss:0.2300  g_loss:3.1911
# 1/1 [==============================] - 0s 17ms/step
# epoch:397  d_loss:0.3593  g_loss:2.3757
# 1/1 [==============================] - 0s 17ms/step
# epoch:398  d_loss:0.3458  g_loss:2.2265
# 1/1 [==============================] - 0s 17ms/step
# epoch:399  d_loss:0.3332  g_loss:2.1336
# 1/1 [==============================] - 0s 16ms/step
# epoch:400  d_loss:0.3757  g_loss:2.0646
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 18ms/step
# epoch:401  d_loss:0.2762  g_loss:2.5926
# 1/1 [==============================] - 0s 17ms/step
# epoch:402  d_loss:0.3420  g_loss:2.4294
# 1/1 [==============================] - 0s 17ms/step
# epoch:403  d_loss:0.3955  g_loss:2.6614
# 1/1 [==============================] - 0s 18ms/step
# epoch:404  d_loss:0.2829  g_loss:2.5086
# 1/1 [==============================] - 0s 22ms/step
# epoch:405  d_loss:0.3181  g_loss:2.9579
# 1/1 [==============================] - 0s 19ms/step
# epoch:406  d_loss:0.2867  g_loss:2.2210
# 1/1 [==============================] - 0s 16ms/step
# epoch:407  d_loss:0.3335  g_loss:2.1219
# 1/1 [==============================] - 0s 16ms/step
# epoch:408  d_loss:0.4326  g_loss:2.0531
# 1/1 [==============================] - 0s 17ms/step
# epoch:409  d_loss:0.4498  g_loss:1.9144
# 1/1 [==============================] - 0s 17ms/step
# epoch:410  d_loss:0.4752  g_loss:2.2032
# 1/1 [==============================] - 0s 16ms/step
# epoch:411  d_loss:0.4952  g_loss:2.7640
# 1/1 [==============================] - 0s 19ms/step
# epoch:412  d_loss:0.4740  g_loss:2.6451
# 1/1 [==============================] - 0s 29ms/step
# epoch:413  d_loss:0.4905  g_loss:1.8845
# 1/1 [==============================] - 0s 26ms/step
# epoch:414  d_loss:0.5112  g_loss:1.9829
# 1/1 [==============================] - 0s 27ms/step
# epoch:415  d_loss:0.3719  g_loss:2.7277
# 1/1 [==============================] - 0s 26ms/step
# epoch:416  d_loss:0.5002  g_loss:2.6452
# 1/1 [==============================] - 0s 25ms/step
# epoch:417  d_loss:0.3487  g_loss:2.0258
# 1/1 [==============================] - 0s 25ms/step
# epoch:418  d_loss:0.3678  g_loss:1.9120
# 1/1 [==============================] - 0s 30ms/step
# epoch:419  d_loss:0.4366  g_loss:2.0163
# 1/1 [==============================] - 0s 24ms/step
# epoch:420  d_loss:0.3801  g_loss:1.7338
# 1/1 [==============================] - 0s 25ms/step
# epoch:421  d_loss:0.5132  g_loss:1.7618
# 1/1 [==============================] - 0s 23ms/step
# epoch:422  d_loss:0.3968  g_loss:1.8598
# 1/1 [==============================] - 0s 24ms/step
# epoch:423  d_loss:0.3838  g_loss:2.2526
# 1/1 [==============================] - 0s 25ms/step
# epoch:424  d_loss:0.4915  g_loss:2.2412
# 1/1 [==============================] - 0s 28ms/step
# epoch:425  d_loss:0.4893  g_loss:1.6410
# 1/1 [==============================] - 0s 36ms/step
# epoch:426  d_loss:0.5644  g_loss:1.4435
# 1/1 [==============================] - 0s 25ms/step
# epoch:427  d_loss:0.4775  g_loss:1.7795
# 1/1 [==============================] - 0s 30ms/step
# epoch:428  d_loss:0.3115  g_loss:1.9300
# 1/1 [==============================] - 0s 31ms/step
# epoch:429  d_loss:0.3733  g_loss:2.1432
# 1/1 [==============================] - 0s 28ms/step
# epoch:430  d_loss:0.3968  g_loss:2.5990
# 1/1 [==============================] - 0s 24ms/step
# epoch:431  d_loss:0.3861  g_loss:2.2750
# 1/1 [==============================] - 0s 21ms/step
# epoch:432  d_loss:0.4878  g_loss:2.2267
# 1/1 [==============================] - 0s 18ms/step
# epoch:433  d_loss:0.3957  g_loss:1.9189
# 1/1 [==============================] - 0s 21ms/step
# epoch:434  d_loss:0.4073  g_loss:1.8291
# 1/1 [==============================] - 0s 17ms/step
# epoch:435  d_loss:0.4375  g_loss:1.9459
# 1/1 [==============================] - 0s 17ms/step
# epoch:436  d_loss:0.3780  g_loss:1.8942
# 1/1 [==============================] - 0s 17ms/step
# epoch:437  d_loss:0.3189  g_loss:1.8967
# 1/1 [==============================] - 0s 17ms/step
# epoch:438  d_loss:0.3839  g_loss:1.8969
# 1/1 [==============================] - 0s 18ms/step
# epoch:439  d_loss:0.3656  g_loss:2.4300
# 1/1 [==============================] - 0s 18ms/step
# epoch:440  d_loss:0.2428  g_loss:2.3786
# 1/1 [==============================] - 0s 16ms/step
# epoch:441  d_loss:0.4096  g_loss:2.0894
# 1/1 [==============================] - 0s 18ms/step
# epoch:442  d_loss:0.2382  g_loss:2.4026
# 1/1 [==============================] - 0s 18ms/step
# epoch:443  d_loss:0.3124  g_loss:2.1468
# 1/1 [==============================] - 0s 19ms/step
# epoch:444  d_loss:0.2010  g_loss:2.6359
# 1/1 [==============================] - 0s 21ms/step
# epoch:445  d_loss:0.2867  g_loss:2.3858
# 1/1 [==============================] - 0s 17ms/step
# epoch:446  d_loss:0.2946  g_loss:2.4200
# 1/1 [==============================] - 0s 19ms/step
# epoch:447  d_loss:0.3582  g_loss:1.9421
# 1/1 [==============================] - 0s 17ms/step
# epoch:448  d_loss:0.3162  g_loss:2.0315
# 1/1 [==============================] - 0s 17ms/step
# epoch:449  d_loss:0.2808  g_loss:2.1128
# 1/1 [==============================] - 0s 17ms/step
# epoch:450  d_loss:0.4500  g_loss:1.8517
# 1/1 [==============================] - 0s 18ms/step
# epoch:451  d_loss:0.3015  g_loss:2.0248
# 1/1 [==============================] - 0s 17ms/step
# epoch:452  d_loss:0.2855  g_loss:2.6127
# 1/1 [==============================] - 0s 17ms/step
# epoch:453  d_loss:0.3623  g_loss:1.9824
# 1/1 [==============================] - 0s 17ms/step
# epoch:454  d_loss:0.3008  g_loss:2.3973
# 1/1 [==============================] - 0s 22ms/step
# epoch:455  d_loss:0.3557  g_loss:1.9374
# 1/1 [==============================] - 0s 18ms/step
# epoch:456  d_loss:0.2999  g_loss:1.9093
# 1/1 [==============================] - 0s 21ms/step
# epoch:457  d_loss:0.3511  g_loss:1.9669
# 1/1 [==============================] - 0s 20ms/step
# epoch:458  d_loss:0.2993  g_loss:2.3327
# 1/1 [==============================] - 0s 20ms/step
# epoch:459  d_loss:0.2690  g_loss:2.3884
# 1/1 [==============================] - 0s 18ms/step
# epoch:460  d_loss:0.3303  g_loss:2.5620
# 1/1 [==============================] - 0s 19ms/step
# epoch:461  d_loss:0.3813  g_loss:2.2087
# 1/1 [==============================] - 0s 18ms/step
# epoch:462  d_loss:0.3217  g_loss:2.0821
# 1/1 [==============================] - 0s 18ms/step
# epoch:463  d_loss:0.3740  g_loss:2.1401
# 1/1 [==============================] - 0s 17ms/step
# epoch:464  d_loss:0.3957  g_loss:2.4575
# 1/1 [==============================] - 0s 19ms/step
# epoch:465  d_loss:0.1673  g_loss:3.0462
# 1/1 [==============================] - 0s 19ms/step
# epoch:466  d_loss:0.2586  g_loss:2.6248
# 1/1 [==============================] - 0s 23ms/step
# epoch:467  d_loss:0.2548  g_loss:2.4509
# 1/1 [==============================] - 0s 18ms/step
# epoch:468  d_loss:0.3712  g_loss:1.8479
# 1/1 [==============================] - 0s 21ms/step
# epoch:469  d_loss:0.2862  g_loss:1.9291
# 1/1 [==============================] - 0s 25ms/step
# epoch:470  d_loss:0.3029  g_loss:2.2527
# 1/1 [==============================] - 0s 19ms/step
# epoch:471  d_loss:0.3589  g_loss:2.6488
# 1/1 [==============================] - 0s 17ms/step
# epoch:472  d_loss:0.3376  g_loss:2.3269
# 1/1 [==============================] - 0s 18ms/step
# epoch:473  d_loss:0.3552  g_loss:2.3519
# 1/1 [==============================] - 0s 21ms/step
# epoch:474  d_loss:0.2252  g_loss:2.1251
# 1/1 [==============================] - 0s 18ms/step
# epoch:475  d_loss:0.4689  g_loss:1.8141
# 1/1 [==============================] - 0s 18ms/step
# epoch:476  d_loss:0.2255  g_loss:2.5878
# 1/1 [==============================] - 0s 18ms/step
# epoch:477  d_loss:0.3506  g_loss:2.2812
# 1/1 [==============================] - 0s 17ms/step
# epoch:478  d_loss:0.3662  g_loss:2.7842
# 1/1 [==============================] - 0s 18ms/step
# epoch:479  d_loss:0.4074  g_loss:2.2115
# 1/1 [==============================] - 0s 18ms/step
# epoch:480  d_loss:0.3457  g_loss:2.4340
# 1/1 [==============================] - 0s 21ms/step
# epoch:481  d_loss:0.4211  g_loss:2.1554
# 1/1 [==============================] - 0s 21ms/step
# epoch:482  d_loss:0.4854  g_loss:1.7250
# 1/1 [==============================] - 0s 22ms/step
# epoch:483  d_loss:0.4837  g_loss:1.5904
# 1/1 [==============================] - 0s 17ms/step
# epoch:484  d_loss:0.4807  g_loss:1.8892
# 1/1 [==============================] - 0s 17ms/step
# epoch:485  d_loss:0.4354  g_loss:2.0604
# 1/1 [==============================] - 0s 19ms/step
# epoch:486  d_loss:0.3700  g_loss:2.0897
# 1/1 [==============================] - 0s 19ms/step
# epoch:487  d_loss:0.3435  g_loss:1.9893
# 1/1 [==============================] - 0s 18ms/step
# epoch:488  d_loss:0.3215  g_loss:2.2809
# 1/1 [==============================] - 0s 20ms/step
# epoch:489  d_loss:0.4087  g_loss:2.0065
# 1/1 [==============================] - 0s 22ms/step
# epoch:490  d_loss:0.3455  g_loss:1.7539
# 1/1 [==============================] - 0s 17ms/step
# epoch:491  d_loss:0.3129  g_loss:2.0991
# 1/1 [==============================] - 0s 19ms/step
# epoch:492  d_loss:0.2511  g_loss:2.3780
# 1/1 [==============================] - 0s 20ms/step
# epoch:493  d_loss:0.3579  g_loss:2.4264
# 1/1 [==============================] - 0s 21ms/step
# epoch:494  d_loss:0.4031  g_loss:2.0620
# 1/1 [==============================] - 0s 18ms/step
# epoch:495  d_loss:0.3899  g_loss:1.9523
# 1/1 [==============================] - 0s 17ms/step
# epoch:496  d_loss:0.2620  g_loss:2.0647
# 1/1 [==============================] - 0s 19ms/step
# epoch:497  d_loss:0.2091  g_loss:2.4462
# 1/1 [==============================] - 0s 17ms/step
# epoch:498  d_loss:0.2388  g_loss:2.4559
# 1/1 [==============================] - 0s 18ms/step
# epoch:499  d_loss:0.3909  g_loss:2.1400
# 1/1 [==============================] - 0s 19ms/step
# epoch:500  d_loss:0.3047  g_loss:1.9774
# 1/1 [==============================] - 0s 17ms/step
# epoch:501  d_loss:0.2122  g_loss:2.2801
# 1/1 [==============================] - 0s 16ms/step
# epoch:502  d_loss:0.2171  g_loss:2.4445
# 1/1 [==============================] - 0s 18ms/step
# epoch:503  d_loss:0.2486  g_loss:2.4951
# 1/1 [==============================] - 0s 17ms/step
# epoch:504  d_loss:0.2280  g_loss:3.0077
# 1/1 [==============================] - 0s 18ms/step
# epoch:505  d_loss:0.2746  g_loss:2.0141
# 1/1 [==============================] - 0s 18ms/step
# epoch:506  d_loss:0.2317  g_loss:2.3035
# 1/1 [==============================] - 0s 18ms/step
# epoch:507  d_loss:0.2201  g_loss:2.2627
# 1/1 [==============================] - 0s 18ms/step
# epoch:508  d_loss:0.2584  g_loss:2.5172
# 1/1 [==============================] - 0s 22ms/step
# epoch:509  d_loss:0.2851  g_loss:2.3294
# 1/1 [==============================] - 0s 19ms/step
# ...
# epoch:1829  d_loss:0.4653  g_loss:1.7385
# 1/1 [==============================] - 0s 22ms/step
# epoch:1830  d_loss:0.4743  g_loss:1.6332
# 1/1 [==============================] - 0s 17ms/step
# epoch:1831  d_loss:0.6093  g_loss:1.6557
# 1/1 [==============================] - 0s 21ms/step
# epoch:1832  d_loss:0.6790  g_loss:1.4138
# 1/1 [==============================] - 0s 19ms/step
# epoch:1833  d_loss:0.5637  g_loss:1.5231
# 1/1 [==============================] - 0s 21ms/step
# epoch:1834  d_loss:0.4292  g_loss:2.0418
# 1/1 [==============================] - 0s 36ms/step
# epoch:1835  d_loss:0.7749  g_loss:1.7480
# 1/1 [==============================] - 0s 35ms/step
# epoch:1836  d_loss:0.5092  g_loss:1.6290
# 1/1 [==============================] - 0s 23ms/step
# epoch:1837  d_loss:0.5312  g_loss:1.6889
# 1/1 [==============================] - 0s 24ms/step
# epoch:1838  d_loss:0.5195  g_loss:1.6097
# 1/1 [==============================] - 0s 37ms/step
# epoch:1839  d_loss:0.5294  g_loss:1.6628
# 1/1 [==============================] - 0s 34ms/step
# epoch:1840  d_loss:0.4398  g_loss:1.7063
# 1/1 [==============================] - 0s 23ms/step
# epoch:1841  d_loss:0.6450  g_loss:1.8922
# 1/1 [==============================] - 0s 31ms/step
# epoch:1842  d_loss:0.5279  g_loss:1.7741
# 1/1 [==============================] - 0s 47ms/step
# epoch:1843  d_loss:0.5170  g_loss:1.7868
# 1/1 [==============================] - 0s 24ms/step
# epoch:1844  d_loss:0.3083  g_loss:1.8300
# 1/1 [==============================] - 0s 27ms/step
# epoch:1845  d_loss:0.4242  g_loss:2.0107
# 1/1 [==============================] - 0s 28ms/step
# epoch:1846  d_loss:0.3154  g_loss:1.6052
# 1/1 [==============================] - 0s 26ms/step
# epoch:1847  d_loss:0.4792  g_loss:1.7893
# 1/1 [==============================] - 0s 25ms/step
# epoch:1848  d_loss:0.4419  g_loss:1.7357
# 1/1 [==============================] - 0s 34ms/step
# epoch:1849  d_loss:0.4807  g_loss:1.5931
# 1/1 [==============================] - 0s 24ms/step
# epoch:1850  d_loss:0.3272  g_loss:1.9794
# 1/1 [==============================] - 0s 32ms/step
# epoch:1851  d_loss:0.4059  g_loss:1.7812
# 1/1 [==============================] - 0s 21ms/step
# epoch:1852  d_loss:0.3847  g_loss:1.5797
# 1/1 [==============================] - 0s 17ms/step
# epoch:1853  d_loss:0.3727  g_loss:1.7926
# 1/1 [==============================] - 0s 23ms/step
# epoch:1854  d_loss:0.5111  g_loss:1.4450
# 1/1 [==============================] - 0s 24ms/step
# epoch:1855  d_loss:0.5061  g_loss:1.8949
# 1/1 [==============================] - 0s 17ms/step
# epoch:1856  d_loss:0.4899  g_loss:1.4090
# 1/1 [==============================] - 0s 22ms/step
# epoch:1857  d_loss:0.5833  g_loss:1.1678
# 1/1 [==============================] - 0s 17ms/step
# epoch:1858  d_loss:0.5069  g_loss:1.4795
# 1/1 [==============================] - 0s 20ms/step
# epoch:1859  d_loss:0.6072  g_loss:1.1921
# 1/1 [==============================] - 0s 17ms/step
# epoch:1860  d_loss:0.4338  g_loss:1.9689
# 1/1 [==============================] - 0s 17ms/step
# epoch:1861  d_loss:0.5706  g_loss:1.8838
# 1/1 [==============================] - 0s 19ms/step
# epoch:1862  d_loss:0.5765  g_loss:1.6489
# 1/1 [==============================] - 0s 16ms/step
# epoch:1863  d_loss:0.5296  g_loss:1.4019
# 1/1 [==============================] - 0s 20ms/step
# epoch:1864  d_loss:0.6086  g_loss:1.7560
# 1/1 [==============================] - 0s 20ms/step
# epoch:1865  d_loss:0.5557  g_loss:1.4687
# 1/1 [==============================] - 0s 22ms/step
# epoch:1866  d_loss:0.5979  g_loss:1.6367
# 1/1 [==============================] - 0s 20ms/step
# epoch:1867  d_loss:0.6532  g_loss:1.2051
# 1/1 [==============================] - 0s 19ms/step
# epoch:1868  d_loss:0.5673  g_loss:1.5104
# 1/1 [==============================] - 0s 17ms/step
# epoch:1869  d_loss:0.4744  g_loss:1.5153
# 1/1 [==============================] - 0s 19ms/step
# epoch:1870  d_loss:0.5381  g_loss:1.5552
# 1/1 [==============================] - 0s 20ms/step
# epoch:1871  d_loss:0.5344  g_loss:1.5539
# 1/1 [==============================] - 0s 17ms/step
# epoch:1872  d_loss:0.5857  g_loss:1.1354
# 1/1 [==============================] - 0s 18ms/step
# epoch:1873  d_loss:0.5643  g_loss:1.1870
# 1/1 [==============================] - 0s 25ms/step
# epoch:1874  d_loss:0.4644  g_loss:1.2619
# 1/1 [==============================] - 0s 22ms/step
# epoch:1875  d_loss:0.4471  g_loss:1.7486
# 1/1 [==============================] - 0s 23ms/step
# epoch:1876  d_loss:0.4708  g_loss:1.6214
# 1/1 [==============================] - 0s 20ms/step
# epoch:1877  d_loss:0.5293  g_loss:1.7399
# 1/1 [==============================] - 0s 22ms/step
# epoch:1878  d_loss:0.4685  g_loss:1.8030
# 1/1 [==============================] - 0s 19ms/step
# epoch:1879  d_loss:0.5433  g_loss:1.2248
# 1/1 [==============================] - 0s 18ms/step
# epoch:1880  d_loss:0.4086  g_loss:1.6821
# 1/1 [==============================] - 0s 25ms/step
# epoch:1881  d_loss:0.4119  g_loss:1.5787
# 1/1 [==============================] - 0s 16ms/step
# epoch:1882  d_loss:0.3618  g_loss:1.5764
# 1/1 [==============================] - 0s 17ms/step
# epoch:1883  d_loss:0.4666  g_loss:1.8681
# 1/1 [==============================] - 0s 17ms/step
# epoch:1884  d_loss:0.3650  g_loss:1.6672
# 1/1 [==============================] - 0s 19ms/step
# epoch:1885  d_loss:0.3940  g_loss:1.9930
# 1/1 [==============================] - 0s 18ms/step
# epoch:1886  d_loss:0.4178  g_loss:2.0250
# 1/1 [==============================] - 0s 22ms/step
# epoch:1887  d_loss:0.3936  g_loss:1.9660
# 1/1 [==============================] - 0s 22ms/step
# epoch:1888  d_loss:0.3913  g_loss:1.5484
# 1/1 [==============================] - 0s 17ms/step
# epoch:1889  d_loss:0.6102  g_loss:1.8429
# 1/1 [==============================] - 0s 21ms/step
# epoch:1890  d_loss:0.5819  g_loss:1.9794
# 1/1 [==============================] - 0s 17ms/step
# epoch:1891  d_loss:0.4001  g_loss:1.9346
# 1/1 [==============================] - 0s 18ms/step
# epoch:1892  d_loss:0.4997  g_loss:1.5354
# 1/1 [==============================] - 0s 17ms/step
# epoch:1893  d_loss:0.5021  g_loss:1.5031
# 1/1 [==============================] - 0s 19ms/step
# epoch:1894  d_loss:0.4401  g_loss:1.7119
# 1/1 [==============================] - 0s 20ms/step
# epoch:1895  d_loss:0.5349  g_loss:2.0059
# 1/1 [==============================] - 0s 18ms/step
# epoch:1896  d_loss:0.4365  g_loss:1.9126
# 1/1 [==============================] - 0s 17ms/step
# epoch:1897  d_loss:0.6009  g_loss:1.7274
# 1/1 [==============================] - 0s 23ms/step
# epoch:1898  d_loss:0.5869  g_loss:1.6151
# 1/1 [==============================] - 0s 23ms/step
# epoch:1899  d_loss:0.5878  g_loss:1.5689
# 1/1 [==============================] - 0s 16ms/step
# epoch:1900  d_loss:0.4844  g_loss:1.6935
# 1/1 [==============================] - 0s 16ms/step
# epoch:1901  d_loss:0.4777  g_loss:1.3732
# 1/1 [==============================] - 0s 17ms/step
# epoch:1902  d_loss:0.4779  g_loss:1.2551
# 1/1 [==============================] - 0s 21ms/step
# epoch:1903  d_loss:0.4907  g_loss:1.6846
# 1/1 [==============================] - 0s 16ms/step
# epoch:1904  d_loss:0.4368  g_loss:1.4915
# 1/1 [==============================] - 0s 19ms/step
# epoch:1905  d_loss:0.4469  g_loss:1.5902
# 1/1 [==============================] - 0s 19ms/step
# epoch:1906  d_loss:0.7428  g_loss:1.4197
# 1/1 [==============================] - 0s 17ms/step
# epoch:1907  d_loss:0.6510  g_loss:1.7382
# 1/1 [==============================] - 0s 20ms/step
# epoch:1908  d_loss:0.4961  g_loss:1.6476
# 1/1 [==============================] - 0s 22ms/step
# epoch:1909  d_loss:0.4531  g_loss:1.4081
# 1/1 [==============================] - 0s 24ms/step
# epoch:1910  d_loss:0.4868  g_loss:1.5248
# 1/1 [==============================] - 0s 16ms/step
# epoch:1911  d_loss:0.4057  g_loss:1.4432
# 1/1 [==============================] - 0s 18ms/step
# epoch:1912  d_loss:0.4707  g_loss:1.7340
# 1/1 [==============================] - 0s 18ms/step
# epoch:1913  d_loss:0.6791  g_loss:1.1943
# 1/1 [==============================] - 0s 16ms/step
# epoch:1914  d_loss:0.6699  g_loss:1.3855
# 1/1 [==============================] - 0s 16ms/step
# epoch:1915  d_loss:0.5955  g_loss:1.7614
# 1/1 [==============================] - 0s 16ms/step
# epoch:1916  d_loss:0.3913  g_loss:1.5598
# 1/1 [==============================] - 0s 19ms/step
# epoch:1917  d_loss:0.6012  g_loss:1.2791
# 1/1 [==============================] - 0s 20ms/step
# epoch:1918  d_loss:0.5762  g_loss:1.5615
# 1/1 [==============================] - 0s 19ms/step
# epoch:1919  d_loss:0.5006  g_loss:1.5602
# 1/1 [==============================] - 0s 22ms/step
# epoch:1920  d_loss:0.5028  g_loss:1.5466
# 1/1 [==============================] - 0s 24ms/step
# epoch:1921  d_loss:0.5907  g_loss:1.3777
# 1/1 [==============================] - 0s 17ms/step
# epoch:1922  d_loss:0.5587  g_loss:1.5763
# 1/1 [==============================] - 0s 17ms/step
# epoch:1923  d_loss:0.4650  g_loss:1.7763
# 1/1 [==============================] - 0s 18ms/step
# epoch:1924  d_loss:0.5269  g_loss:2.0997
# 1/1 [==============================] - 0s 17ms/step
# epoch:1925  d_loss:0.4161  g_loss:2.1148
# 1/1 [==============================] - 0s 17ms/step
# epoch:1926  d_loss:0.5079  g_loss:1.8123
# 1/1 [==============================] - 0s 19ms/step
# epoch:1927  d_loss:0.6379  g_loss:1.2195
# 1/1 [==============================] - 0s 21ms/step
# epoch:1928  d_loss:0.4102  g_loss:1.8717
# 1/1 [==============================] - 0s 23ms/step
# epoch:1929  d_loss:0.4170  g_loss:1.5397
# 1/1 [==============================] - 0s 20ms/step
# epoch:1930  d_loss:0.3778  g_loss:1.5534
# 1/1 [==============================] - 0s 19ms/step
# epoch:1931  d_loss:0.3660  g_loss:1.6409
# 1/1 [==============================] - 0s 18ms/step
# epoch:1932  d_loss:0.4489  g_loss:2.0000
# 1/1 [==============================] - 0s 20ms/step
# epoch:1933  d_loss:0.5412  g_loss:1.8574
# 1/1 [==============================] - 0s 20ms/step
# epoch:1934  d_loss:0.6867  g_loss:1.3391
# 1/1 [==============================] - 0s 16ms/step
# epoch:1935  d_loss:0.5280  g_loss:1.5663
# 1/1 [==============================] - 0s 17ms/step
# epoch:1936  d_loss:0.5444  g_loss:1.7613
# 1/1 [==============================] - 0s 25ms/step
# epoch:1937  d_loss:0.4110  g_loss:2.0720
# 1/1 [==============================] - 0s 22ms/step
# epoch:1938  d_loss:0.3386  g_loss:1.9548
# 1/1 [==============================] - 0s 24ms/step
# epoch:1939  d_loss:0.3944  g_loss:1.7483
# 1/1 [==============================] - 0s 23ms/step
# epoch:1940  d_loss:0.3974  g_loss:1.6007
# 1/1 [==============================] - 0s 22ms/step
# epoch:1941  d_loss:0.5652  g_loss:1.5429
# 1/1 [==============================] - 0s 22ms/step
# epoch:1942  d_loss:0.4904  g_loss:1.5071
# 1/1 [==============================] - 0s 16ms/step
# epoch:1943  d_loss:0.5486  g_loss:1.3885
# 1/1 [==============================] - 0s 16ms/step
# epoch:1944  d_loss:0.4839  g_loss:1.7467
# 1/1 [==============================] - 0s 17ms/step
# epoch:1945  d_loss:0.5201  g_loss:1.6795
# 1/1 [==============================] - 0s 17ms/step
# epoch:1946  d_loss:0.5345  g_loss:2.0750
# 1/1 [==============================] - 0s 16ms/step
# epoch:1947  d_loss:0.5702  g_loss:1.7803
# 1/1 [==============================] - 0s 20ms/step
# epoch:1948  d_loss:0.5117  g_loss:1.3748
# 1/1 [==============================] - 0s 21ms/step
# epoch:1949  d_loss:0.4844  g_loss:1.3860
# 1/1 [==============================] - 0s 32ms/step
# epoch:1950  d_loss:0.5198  g_loss:1.2128
# 1/1 [==============================] - 0s 29ms/step
# epoch:1951  d_loss:0.5056  g_loss:1.0236
# 1/1 [==============================] - 0s 29ms/step
# epoch:1952  d_loss:0.5333  g_loss:1.6096
# 1/1 [==============================] - 0s 27ms/step
# epoch:1953  d_loss:0.6226  g_loss:1.6069
# 1/1 [==============================] - 0s 23ms/step
# epoch:1954  d_loss:0.4734  g_loss:1.4447
# 1/1 [==============================] - 0s 23ms/step
# epoch:1955  d_loss:0.4937  g_loss:1.7298
# 1/1 [==============================] - 0s 40ms/step
# epoch:1956  d_loss:0.5034  g_loss:1.5410
# 1/1 [==============================] - 0s 30ms/step
# epoch:1957  d_loss:0.3275  g_loss:1.9088
# 1/1 [==============================] - 0s 32ms/step
# epoch:1958  d_loss:0.4625  g_loss:1.8599
# 1/1 [==============================] - 0s 30ms/step
# epoch:1959  d_loss:0.5279  g_loss:1.7243
# 1/1 [==============================] - 0s 34ms/step
# epoch:1960  d_loss:0.3725  g_loss:1.3699
# 1/1 [==============================] - 0s 53ms/step
# epoch:1961  d_loss:0.5195  g_loss:1.6247
# 1/1 [==============================] - 0s 26ms/step
# epoch:1962  d_loss:0.3586  g_loss:1.5807
# 1/1 [==============================] - 0s 32ms/step
# epoch:1963  d_loss:0.4896  g_loss:1.5829
# 1/1 [==============================] - 0s 42ms/step
# epoch:1964  d_loss:0.3738  g_loss:1.8061
# 1/1 [==============================] - 0s 28ms/step
# epoch:1965  d_loss:0.5170  g_loss:1.7533
# 1/1 [==============================] - 0s 32ms/step
# epoch:1966  d_loss:0.5902  g_loss:1.7352
# 1/1 [==============================] - 0s 25ms/step
# epoch:1967  d_loss:0.6575  g_loss:1.3868
# 1/1 [==============================] - 0s 18ms/step
# epoch:1968  d_loss:0.4711  g_loss:1.5758
# 1/1 [==============================] - 0s 16ms/step
# epoch:1969  d_loss:0.4084  g_loss:1.3163
# 1/1 [==============================] - 0s 17ms/step
# epoch:1970  d_loss:0.5303  g_loss:1.3839
# 1/1 [==============================] - 0s 24ms/step
# epoch:1971  d_loss:0.5149  g_loss:1.4299
# 1/1 [==============================] - 0s 23ms/step
# epoch:1972  d_loss:0.5365  g_loss:1.3445
# 1/1 [==============================] - 0s 21ms/step
# epoch:1973  d_loss:0.5022  g_loss:1.3648
# 1/1 [==============================] - 0s 20ms/step
# epoch:1974  d_loss:0.4665  g_loss:1.4386
# 1/1 [==============================] - 0s 17ms/step
# epoch:1975  d_loss:0.4863  g_loss:1.6538
# 1/1 [==============================] - 0s 16ms/step
# epoch:1976  d_loss:0.5721  g_loss:1.4534
# 1/1 [==============================] - 0s 17ms/step
# epoch:1977  d_loss:0.3905  g_loss:1.6280
# 1/1 [==============================] - 0s 18ms/step
# epoch:1978  d_loss:0.4839  g_loss:1.9065
# 1/1 [==============================] - 0s 20ms/step
# epoch:1979  d_loss:0.4941  g_loss:1.4379
# 1/1 [==============================] - 0s 17ms/step
# epoch:1980  d_loss:0.4963  g_loss:1.6691
# 1/1 [==============================] - 0s 16ms/step
# epoch:1981  d_loss:0.4511  g_loss:1.5470
# 1/1 [==============================] - 0s 19ms/step
# epoch:1982  d_loss:0.4510  g_loss:1.3254
# 1/1 [==============================] - 0s 17ms/step
# epoch:1983  d_loss:0.5887  g_loss:1.4769
# 1/1 [==============================] - 0s 16ms/step
# epoch:1984  d_loss:0.3886  g_loss:1.4516
# 1/1 [==============================] - 0s 17ms/step
# epoch:1985  d_loss:0.4546  g_loss:1.2319
# 1/1 [==============================] - 0s 16ms/step
# epoch:1986  d_loss:0.4304  g_loss:1.6747
# 1/1 [==============================] - 0s 17ms/step
# epoch:1987  d_loss:0.4950  g_loss:1.6731
# 1/1 [==============================] - 0s 23ms/step
# epoch:1988  d_loss:0.4564  g_loss:1.9837
# 1/1 [==============================] - 0s 18ms/step
# epoch:1989  d_loss:0.5283  g_loss:1.7769
# 1/1 [==============================] - 0s 23ms/step
# epoch:1990  d_loss:0.6046  g_loss:1.2733
# 1/1 [==============================] - 0s 16ms/step
# epoch:1991  d_loss:0.5891  g_loss:1.3862
# 1/1 [==============================] - 0s 19ms/step
# epoch:1992  d_loss:0.5343  g_loss:1.2662
# 1/1 [==============================] - 0s 18ms/step
# epoch:1993  d_loss:0.5130  g_loss:1.2793
# 1/1 [==============================] - 0s 19ms/step
# epoch:1994  d_loss:0.4190  g_loss:1.5249
# 1/1 [==============================] - 0s 17ms/step
# epoch:1995  d_loss:0.4117  g_loss:1.5641
# 1/1 [==============================] - 0s 20ms/step
# epoch:1996  d_loss:0.5527  g_loss:1.6253
# 1/1 [==============================] - 0s 26ms/step
# epoch:1997  d_loss:0.5198  g_loss:1.4158
# 1/1 [==============================] - 0s 19ms/step
# epoch:1998  d_loss:0.6007  g_loss:1.4047
# 1/1 [==============================] - 0s 17ms/step
# epoch:1999  d_loss:0.5959  g_loss:1.7077
# 1/1 [==============================] - 0s 24ms/step
# epoch:2000  d_loss:0.5802  g_loss:1.4773
# 1/1 [==============================] - 0s 17ms/step

# %% [markdown]
# ## 4. 이미지의 특징을 추출하는 오토인코더

# %% [markdown]
# ### 실습: 오토인코더 실습하기

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, Flatten, Reshape

import matplotlib.pyplot as plt
import numpy as np

# MNIST 데이터셋을 불러옵니다.

(X_train, _), (X_test, _) = mnist.load_data()
X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32') / 255
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1).astype('float32') / 255

# 생성자 모델을 만듭니다.
autoencoder = Sequential()

# 인코딩 부분입니다.
autoencoder.add(Conv2D(16, kernel_size=3, padding='same', input_shape=(28,28,1), activation='relu'))
autoencoder.add(MaxPooling2D(pool_size=2, padding='same'))
autoencoder.add(Conv2D(8, kernel_size=3, activation='relu', padding='same'))
autoencoder.add(MaxPooling2D(pool_size=2, padding='same'))
autoencoder.add(Conv2D(8, kernel_size=3, strides=2, padding='same', activation='relu'))

# 디코딩 부분입니다. 
autoencoder.add(Conv2D(8, kernel_size=3, padding='same', activation='relu'))
autoencoder.add(UpSampling2D())
autoencoder.add(Conv2D(8, kernel_size=3, padding='same', activation='relu'))
autoencoder.add(UpSampling2D())
autoencoder.add(Conv2D(16, kernel_size=3, activation='relu'))
autoencoder.add(UpSampling2D())
autoencoder.add(Conv2D(1, kernel_size=3, padding='same', activation='sigmoid'))

# 전체 구조를 확인합니다.
autoencoder.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 28, 28, 16)        160
#
#  max_pooling2d (MaxPooling2D  (None, 14, 14, 16)       0
#  )
#
#  conv2d_5 (Conv2D)           (None, 14, 14, 8)         1160
#
#  max_pooling2d_1 (MaxPooling  (None, 7, 7, 8)          0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 4, 4, 8)           584
#
#  conv2d_7 (Conv2D)           (None, 4, 4, 8)           584
#
#  up_sampling2d_2 (UpSampling  (None, 8, 8, 8)          0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 8, 8, 8)           584
#
#  up_sampling2d_3 (UpSampling  (None, 16, 16, 8)        0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 14, 14, 16)        1168
#
#  up_sampling2d_4 (UpSampling  (None, 28, 28, 16)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 28, 28, 1)         145
#
# =================================================================
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 컴파일 및 학습을 하는 부분입니다.
autoencoder.compile(optimizer='adam', loss='binary_crossentropy')
autoencoder.fit(X_train, X_train, epochs=50, batch_size=128, validation_data=(X_test, X_test))

# 학습된 결과를 출력하는 부분입니다.
random_test = np.random.randint(X_test.shape[0], size=5)  # 테스트할 이미지를 랜덤하게 불러옵니다.
ae_imgs = autoencoder.predict(X_test)                     # 앞서 만든 오토인코더 모델에 집어 넣습니다.

plt.figure(figsize=(7, 2))                         # 출력될 이미지의 크기를 정합니다.

for i, image_idx in enumerate(random_test):        # 랜덤하게 뽑은 이미지를 차례로 나열합니다.
   ax = plt.subplot(2, 7, i + 1) 
   plt.imshow(X_test[image_idx].reshape(28, 28))   # 테스트할 이미지를 먼저 그대로 보여줍니다.
   ax.axis('off')
   ax = plt.subplot(2, 7, 7 + i +1)
   plt.imshow(ae_imgs[image_idx].reshape(28, 28))  # 오토인코딩 결과를 다음열에 출력합니다.
   ax.axis('off')
plt.show()
# Out:
# Epoch 1/50
# 469/469 [==============================] - 7s 8ms/step - loss: 0.2102 - val_loss: 0.1354
# Epoch 2/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1239 - val_loss: 0.1152
# Epoch 3/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1118 - val_loss: 0.1073
# Epoch 4/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.1058 - val_loss: 0.1024
# Epoch 5/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.1016 - val_loss: 0.0986
# Epoch 6/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0986 - val_loss: 0.0968
# Epoch 7/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0964 - val_loss: 0.0948
# Epoch 8/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0946 - val_loss: 0.0931
# Epoch 9/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0932 - val_loss: 0.0923
# Epoch 10/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0921 - val_loss: 0.0903
# Epoch 11/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0910 - val_loss: 0.0897
# Epoch 12/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0902 - val_loss: 0.0887
# Epoch 13/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0895 - val_loss: 0.0880
# Epoch 14/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0888 - val_loss: 0.0874
# Epoch 15/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0882 - val_loss: 0.0868
# Epoch 16/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0877 - val_loss: 0.0867
# Epoch 17/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0873 - val_loss: 0.0859
# Epoch 18/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0869 - val_loss: 0.0857
# Epoch 19/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0865 - val_loss: 0.0856
# Epoch 20/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0861 - val_loss: 0.0851
# Epoch 21/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0858 - val_loss: 0.0846
# Epoch 22/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0856 - val_loss: 0.0843
# Epoch 23/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0852 - val_loss: 0.0841
# Epoch 24/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0850 - val_loss: 0.0837
# Epoch 25/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0847 - val_loss: 0.0834
# Epoch 26/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0844 - val_loss: 0.0833
# Epoch 27/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0843 - val_loss: 0.0833
# Epoch 28/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0840 - val_loss: 0.0828
# Epoch 29/50
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0839 - val_loss: 0.0827
# Epoch 30/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0836 - val_loss: 0.0827
# Epoch 31/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0835 - val_loss: 0.0823
# Epoch 32/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0833 - val_loss: 0.0821
# Epoch 33/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0831 - val_loss: 0.0820
# Epoch 34/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0830 - val_loss: 0.0822
# Epoch 35/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0828 - val_loss: 0.0818
# Epoch 36/50
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0827 - val_loss: 0.0818
# Epoch 37/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0826 - val_loss: 0.0815
# Epoch 38/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0825 - val_loss: 0.0814
# Epoch 39/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0823 - val_loss: 0.0813
# Epoch 40/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0822 - val_loss: 0.0813
# Epoch 41/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0822 - val_loss: 0.0811
# Epoch 42/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0820 - val_loss: 0.0809
# Epoch 43/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0819 - val_loss: 0.0811
# Epoch 44/50
# 469/469 [==============================] - 4s 8ms/step - loss: 0.0818 - val_loss: 0.0810
# Epoch 45/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0818 - val_loss: 0.0808
# Epoch 46/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0817 - val_loss: 0.0807
# Epoch 47/50
# 469/469 [==============================] - 4s 7ms/step - loss: 0.0816 - val_loss: 0.0805
# Epoch 48/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0815 - val_loss: 0.0804
# Epoch 49/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0814 - val_loss: 0.0805
# Epoch 50/50
# 469/469 [==============================] - 3s 7ms/step - loss: 0.0814 - val_loss: 0.0804
# 313/313 [==============================] - 1s 2ms/step
