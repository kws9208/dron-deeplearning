# %% [markdown]
# ## 코랩 연결 끊김 방지
#
#
#
# ```
# function ClickConnect(){
#   console.log("Connnect Clicked - Start");
#   document.querySelector("#top-toolbar > colab-connect-button").shadowRoot.querySelector("#connect").click();
#   console.log("Connnect Clicked - End");
# };
# var clickid = setInterval(ClickConnect, 60*1000)
#
# clearInterval(clickid);
# ```

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !git clone --recurse-submodules https://github.com/mikel-brostrom/yolov8_tracking.git  # clone recursively
# %cd yolov8_tracking
# !pip install -r requirements.txt  # install dependencies
# Out:
# Cloning into 'yolov8_tracking'...
# remote: Enumerating objects: 4560, done.
# remote: Counting objects: 100% (152/152), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 4560 (delta 71), reused 129 (delta 59), pack-reused 4408
# Receiving objects: 100% (4560/4560), 109.42 MiB | 15.65 MiB/s, done.
# Resolving deltas: 100% (2323/2323), done.
# Updating files: 100% (148/148), done.
# Submodule 'yolov8' (https://github.com/ultralytics/ultralytics) registered for path 'yolov8'
# Cloning into '/content/drive/MyDrive/yolov8_tracking/yolov8'...
# remote: Enumerating objects: 5076, done.
# remote: Counting objects: 100% (269/269), done.
# remote: Compressing objects: 100% (219/219), done.
# remote: Total 5076 (delta 126), reused 119 (delta 50), pack-reused 4807
# Receiving objects: 100% (5076/5076), 4.28 MiB | 6.41 MiB/s, done.
# Resolving deltas: 100% (3300/3300), done.
# Submodule path 'yolov8': checked out '15b3b0365ab2f12993a58985f3cb7f2137409a0c'
# ...

# %%
# !python track.py --source /content/drive/MyDrive/yolov5/dron/220503남서울대정문1225_colab.MP4 --yolo-weights yolov8s-seg.pt --reid-weights osnet_x0_25_market1501.pt --img 640 --save-vid
# Out:
# track: yolo_weights=[PosixPath('yolov8s-seg.pt')], reid_weights=osnet_x0_25_market1501.pt, tracking_method=bytetrack, tracking_config=trackers/bytetrack/configs/bytetrack.yaml, source=/content/drive/MyDrive/yolov5/dron/220503남서울대정문1225_colab.MP4, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.5, max_det=1000, device=, show_vid=False, save_txt=False, save_conf=False, save_crop=False, save_trajectories=False, save_vid=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/track, name=exp, exist_ok=False, line_thickness=2, hide_labels=False, hide_conf=False, hide_class=False, half=False, dnn=False, vid_stride=1, retina_masks=False
# Ultralytics YOLOv8.0.20 🚀 Python-3.8.10 torch-1.13.1+cu116 CPU
# ...
# 100% 22.8M/22.8M [00:00<00:00, 80.3MB/s]
#
# YOLOv8s-seg summary (fused): 195 layers, 11810560 parameters, 0 gradients, 42.6 GFLOPs
# ...

# %%
# !ffmpeg -i /content/drive/MyDrive/yolov8_tracking/runs/track/exp2/dron.mp4 -vf fps=30 -vcodec libx264 dron_output2.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open('dron_output2.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

# %%
HTML("""
<video controls height="540" width="960">
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# ---

# %%
# !python track.py --source /content/drive/MyDrive/video/bb_3_181207_two-wheeled-vehicle_229_22055.mp4 --yolo-weights yolov8s-seg.pt --reid-weights osnet_x0_25_market1501.pt --img 640 --save-vid
# Out:
# track: yolo_weights=[PosixPath('yolov8s-seg.pt')], reid_weights=osnet_x0_25_market1501.pt, tracking_method=bytetrack, tracking_config=trackers/bytetrack/configs/bytetrack.yaml, source=/content/drive/MyDrive/video/bb_3_181207_two-wheeled-vehicle_229_22055.mp4, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.5, max_det=1000, device=, show_vid=False, save_txt=False, save_conf=False, save_crop=False, save_trajectories=False, save_vid=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/track, name=exp, exist_ok=False, line_thickness=2, hide_labels=False, hide_conf=False, hide_class=False, half=False, dnn=False, vid_stride=1, retina_masks=False
# Ultralytics YOLOv8.0.20 🚀 Python-3.8.10 torch-1.13.1+cu116 CPU
# YOLOv8s-seg summary (fused): 195 layers, 11810560 parameters, 0 gradients, 42.6 GFLOPs
# video 1/1 (1/150) /content/drive/MyDrive/video/bb_3_181207_two-wheeled-vehicle_229_22055.mp4: 384x640 1 car, 894.1ms
# ...

# %%
# !ffmpeg -i /content/drive/MyDrive/yolov8_tracking/runs/track/exp3/bb_3_181207_two-wheeled-vehicle_229_22055.mp4 -vf fps=30 -vcodec libx264 blackbox.mp4
# Out:
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
# ...

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open('blackbox.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

# %%
HTML("""
<video controls height="540" width="960">
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video controls height="540" width="960">
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>

# %%
# !pip uninstall opencv-python
# !pip install opencv-python
# Out:
# Found existing installation: opencv-python 4.7.0.72
# Uninstalling opencv-python-4.7.0.72:
#   Would remove:
#     /usr/local/lib/python3.8/dist-packages/cv2/*
#     /usr/local/lib/python3.8/dist-packages/opencv_python-4.7.0.72.dist-info/*
#     /usr/local/lib/python3.8/dist-packages/opencv_python.libs/libQt5Core-39545cc7.so.5.15.0
#     /usr/local/lib/python3.8/dist-packages/opencv_python.libs/libQt5Gui-48e93776.so.5.15.0
#     /usr/local/lib/python3.8/dist-packages/opencv_python.libs/libQt5Test-c38a5234.so.5.15.0
#     /usr/local/lib/python3.8/dist-packages/opencv_python.libs/libQt5Widgets-e69d94fb.so.5.15.0
#     /usr/local/lib/python3.8/dist-packages/opencv_python.libs/libQt5XcbQpa-c112ba75.so.5.15.0
#     /usr/local/lib/python3.8/dist-packages/opencv_python.libs/libX11-xcb-69166bdf.so.1.0.0
#     /usr/local/lib/python3.8/dist-packages/opencv_python.libs/libXau-00ec42fe.so.6.0.0
#     /usr/local/lib/python3.8/dist-packages/opencv_python.libs/libavcodec-16a334ab.so.59.37.100
# ...

# %%
# !python track.py --source "https://www.youtube.com/watch?v=QLPrvVS2600" --yolo-weights yolov8s-seg.pt --reid-weights osnet_x0_25_market1501.pt --img 640 --save-vid
# Out:
# track: yolo_weights=[PosixPath('yolov8s-seg.pt')], reid_weights=/content/drive/MyDrive/yolov8_tracking/weights/osnet_x0_25_msmt17.pt, tracking_method=bytetrack, tracking_config=trackers/bytetrack/configs/bytetrack.yaml, source=https://www.youtube.com/watch?v=QLPrvVS2600, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.5, max_det=1000, device=, show_vid=False, save_txt=False, save_conf=False, save_crop=False, save_trajectories=False, save_vid=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/track, name=exp, exist_ok=False, line_thickness=2, hide_labels=False, hide_conf=False, hide_class=False, half=False, dnn=False, vid_stride=1, retina_masks=False
# Ultralytics YOLOv8.0.20 🚀 Python-3.8.10 torch-1.13.1+cu116 CPU
# YOLOv8s-seg summary (fused): 195 layers, 11810560 parameters, 0 gradients, 42.6 GFLOPs
# qt.qpa.xcb: could not connect to display
# ...

# %%
# !ffmpeg -i /content/drive/MyDrive/yolov8_tracking/runs/track/exp3/bb_3_181207_two-wheeled-vehicle_229_22055.mp4 -vf fps=30 -vcodec libx264 blackbox.mp4

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open('blackbox.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

# %%
HTML("""
<video controls height="540" width="960">
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
